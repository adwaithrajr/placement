# %% [markdown]
# <a href="https://colab.research.google.com/github/adwaithrajr/placement/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def monkey_baa():
  try:
    n=int(input())
    k=int(input())
    j=int(input())
    m=int(input())
    p=int(input())

    if n<0 or k<=0 or j<=0 or m<0 or p<0:
      print("INVALID INPUT")
      return


    ate_bananas = m/k
    ate_peanuts = p/j
    total_ate = ate_bananas + ate_peanuts

    if (m % k) != 0 or (p % j) != 0:
      total_ate +=1

    monkeys_baa = n - total_ate
    if monkeys_baa < 0:
      monkeys_baa = 0

    print(f"number of monkeys left on the tree:{int(monkeys_baa)}")
  except ValueError:
    print("INVALID INPUT")

if __name__ == "__main__":
  monkey_baa()
# Out:
# 20
# 2
# 3
# 12
# 12
# number of monkeys left on the tree:10

# %%
x=10
y=7
temp=x
x=y
y=temp
print("value of x after swapping::{}".format(x))
print("value of x after swapping::{}".format(y))
# Out:
# value of x after swapping::7
# value of x after swapping::10

# %%
x=100
y=7
x,y=y,x
print("x=",x)
print("y=",y)
# Out:
# x= 7
# y= 100

# %%
a=int(input("enter the number first "))
b=int(input("enter the number second "))
print ("condition using + and -")
a=a+b
b=a-b
a=a-b
print ("swap 1 a =",a)
print ("swap 1 b =",b)
print ("condition using xor")
a=a^b
b=a^b
a=a^b
print ("swap 2 a =",a)
print ("swap 2 b =",b)
print ("condition using ,")
a,b=b,a
print ("swap 3 a =",a)
print ("swap 3 b =",b)
print ("condition using temp")
temp=a
a=b
b=temp
print ("swap 4 a =",a)
print ("swap 4 b =",b)
# Out:
# enter the number first 10
# enter the number second 20
# condition using + and -
# swap 1 a = 20
# swap 1 b = 10
# condition using xor
# swap 2 a = 10
# swap 2 b = 20
# condition using ,
# swap 3 a = 20
# swap 3 b = 10
# condition using temp
# swap 4 a = 10
# swap 4 b = 20

# %%
n=int(input("Enter max no. of candies:"))
k=int(input("Enter min no. of candies:"))
con=1
r=n
while(con==1):
  m=int(input("Enter amout of candies needed:"))
  if(m>n):
    print("invalid")
  else:
    r=r-m
    if(r<=k):
      r=n
    print("Sold=",m)
    print("Remaining=",r)
    con=int(input("press 0 to exit and 1 to continue:"))
# Out:
# Enter max no. of candies:10
# Enter min no. of candies:5
# Enter amout of candies needed:3
# Sold= 3
# Remaining= 7

# %%
n =int(input("enter the elements"))
arr =list(map(int,input("enter the elemnets:").split()))
largest = arr[20]
for i in range(1,n):
  if arr[i]>largest:
    largest=arr[i]
print("largest element is",largest)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2998/2810919247.py in <cell line: 0>()
# ----> 1 n =int(input("enter the elements"))
#       2 arr =list(map(int,input("enter the elemnets:").split()))
#       3 largest = arr[20]
#       4 for i in range(1,n):
#       5   if arr[i]>largest:
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
n =int(input("enter the elements:"))
arr =list(map(int,input("enter the elemnets:").split()))
smallest = arr[0]
for i in range(1,n):
  if arr[i]<smallest:
    smallest = arr[i]
print("smallest element is",smallest)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2998/639617337.py in <cell line: 0>()
# ----> 1 n =int(input("enter the elements:"))
#       2 arr =list(map(int,input("enter the elemnets:").split()))
#       3 smallest = arr[0]
#       4 for i in range(1,n):
#       5   if arr[i]<smallest:
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
n =int(input("enter the elements:"))
arr =list(map(int,input("enter the elemnets:").split()))
total =0
for i in range(n):
  total = total + arr[i]
  print("sum of elements:",total)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2998/2775708585.py in <cell line: 0>()
# ----> 1 n =int(input("enter the elements:"))
#       2 arr =list(map(int,input("enter the elemnets:").split()))
#       3 total =0
#       4 for i in range(n):
#       5   total = total + arr[i]
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
n =int(input("enter the elements:"))
arr =list(map(int,input("enter the elemnets:").split()))
total = 0
for i in range(n):
  total = total + arr[i]
  print("sum of elements:",total)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2998/286530730.py in <cell line: 0>()
# ----> 1 n =int(input("enter the elements:"))
#       2 arr =list(map(int,input("enter the elemnets:").split()))
#       3 total = 0
#       4 for i in range(n):
#       5   total = total + arr[i]
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
n =int(input("enter the elements:"))
arr =list(map(int,input("enter the elemnets:").split()))
reverse = arr[::-1]
print("reversed arry:",reverse)
# Out:
# enter the elements:5
# enter the elemnets:10 20 30 40 50
# reversed arry: [50, 40, 30, 20, 10]

# %%
n =int(input("enter the elements:"))
arr =list(map(int,input("enter the elemnets:").split()))
x =int(input("enter elements to search:"))
if x in arr:
  print("elements exist")
else:
  print("elements does not exist")
# Out:
# enter the elements:5
# enter the elemnets:10 20 30 40 50
# enter elements to search:30
# elements exist

# %%
n =int(input("enter number of elements:"))
arr =list(map(int,input("enter the elements:").split()))
x =int(input("enter elements to count:",))
count = 0
for i in range(n):
  if arr[i] == x:
    count += 1
print("number of occurrences:",count)
# Out:
# enter number of elements:6
# enter the elements:10 20 10 30 10 40
# enter elements to count:10
# number of occurrences: 3

# %%
n =int(input("enter number of elements:"))
arr =list(map(int,input("enter the elements:").split()))
largest = second = float('-inf')
for x in arr:
  if x > largest:
    second = largest
    largest = x
  elif x > second and x != largest:
    second = x
print("second largest element:",second)
# Out:
# enter number of elements:5
# enter the elements:10 25 7 42 18
# second largest element: 25

# %%
from enum import unique
n =int(input("enter number of elements:"))
arr =list(map(int,input("enter the elements:").split()))
unique =[]
for x in arr:
  if x not in unique:
    unique.append(x)
print("array after removing duplicates:",unique)
# Out:
# enter number of elements:6
# enter the elements:10 20 10 30 20 40
# array after removing duplicates: [10, 20, 30, 40]

# %%
n =int(input("enter number of elements:"))
arr =list(map(int,input("enter the elements:").split()))
arr.sort()
print("sorted array:",arr)
# Out:
# enter number of elements:5
# enter the elements:30 10 50 20 40
# sorted array: [10, 20, 30, 40, 50]

# %%
n =int(input("enter number of elements:"))
arr =list(map(int,input("enter the elements:").split()))
print("array:",arr)
# Out:
# enter number of elements:5
# enter the elements:10 20 30 40 50
# sorted array: [10, 20, 30, 40, 50]
